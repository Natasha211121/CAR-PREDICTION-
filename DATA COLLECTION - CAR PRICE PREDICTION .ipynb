# %% [markdown]
# ## DATA COLLECTION - CAR PRICE PREDICTION

# %%
import pandas as pd
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
import os
os.getcwd()
# Out:
# '/Users/natashapoddar'

# %%
driver=webdriver.Chrome(r"/Users/natashapoddar/chromedriver")

# %%
driver.get('https://www.cars24.com/')

# %%
btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/ul/li[1]')
btn.click()

# %% [markdown]
# ## 927 cars in DELHI , emi option yes, zero dp

# %%
year=[]
aa=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in aa:
    year.append(i.text.split()[0])

# %%
brand=[]
aaa=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in aaa:
    brand.append(i.text.split()[1])

# %%
model=[]
aaaa=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in aaaa:
    model.append(i.text.split()[2:])

# %%
km=[]
ss=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in ss:
    km.append(i.text.split()[0])

# %%
make=[]
sss=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in sss:
    make.append(i.text.split()[4:7])

# %%
price=[]
d=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in d:
    price.append(i.text)

# %%
price
# Out:
# ['₹5,38,799',
#  '₹5,34,399',
#  '₹5,56,899',
#  '₹2,23,699',
#  '₹5,21,999',
#  '₹5,56,199',
#  '₹5,57,199',
#  '₹5,63,699',
#  '₹2,36,999',
#  '₹2,25,299',
#  '₹2,76,699',
#  '₹8,08,399',
#  '₹19,29,699',
#  '₹17,22,599',
#  '₹5,09,899',
#  '₹5,92,499',
#  '₹5,44,599',
#  '₹5,69,799',
#  '₹2,81,499',
#  '₹6,88,499',
#  '₹5,59,999',
#  '₹16,67,299',
#  '₹1,59,999',
#  '₹17,71,299',
#  '₹16,66,999',
#  '₹2,85,699',
#  '₹7,20,176',
#  '',
#  '',
#  '₹5,37,399',
#  '₹9,68,199',
#  '₹3,83,699',
#  '₹8,43,899',
#  '₹13,69,099',
#  '₹2,80,099',
#  '',
#  '₹2,44,199',
#  '₹5,34,799',
#  '₹5,07,099',
#  '₹6,03,599',
#  '₹4,58,549',
#  '₹7,18,899',
#  '₹7,56,599',
#  '₹5,01,199',
#  '₹2,92,099',
#  '₹3,90,399',
#  '₹2,55,299',
#  '₹6,03,599',
#  '₹2,03,399',
#  '₹1,93,699',
#  '₹6,03,099',
#  '₹2,29,899',
#  '₹3,49,399',
#  '₹7,02,999',
#  '₹2,03,699',
#  '₹4,39,799',
#  '₹5,45,099',
#  '₹8,97,899',
#  '₹1,84,099',
#  '₹5,18,499',
#  '₹2,76,299',
#  '₹2,07,899',
#  '₹14,22,399',
# ...

# %%
zdp=[]
dd=driver.find_elements(By.XPATH,'//span[@class="_3X7mV _2H07I"]')
for i in dd:
    zdp.append(i.text)

# %%
typee=[]
fr=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in fr:
    typee.append(i.text.split()[-1])

# %%
len(typee)
# Out:
# 926

# %%
print(len(make),len(km),len(model),len(brand),len(year),len(zdp),len(price),len(typee))
# Out:
# 926 926 926 926 926 926 926 926

# %%
delhi=pd.DataFrame({'YEAR':year,'BRAND':brand,'MAKE':make,'KM':km,'MODEL':model,'ZDP':zdp,'TYPE':typee,'PRICE':price})

# %%
delhi
# Out:
#      YEAR    BRAND              MAKE      KM         MODEL                ZDP  \
# 0    2019   Maruti          [Petrol]  12,046       [Swift]  Zero Down Payment
# 1    2019   Maruti          [Petrol]  11,404       [Swift]  Zero Down Payment
# 2    2018  Hyundai          [Petrol]   6,875  [Grand, i10]  Zero Down Payment
# 3    2018   Datsun          [Petrol]  15,576    [Redi, Go]  Zero Down Payment
# 4    2018  Hyundai          [Petrol]  12,362  [Grand, i10]  Zero Down Payment
# ..    ...      ...               ...     ...           ...                ...
# 921  2020   Maruti          [Petrol]  39,932      [Baleno]  Zero Down Payment
# 922  2016  Hyundai          [Petrol]  16,917  [Elite, i20]  Zero Down Payment
# 923  2018  Renault          [Petrol]  72,630        [Kwid]  Zero Down Payment
# 924  2021     Ford          [Diesel]  35,576    [Ecosport]  Zero Down Payment
# 925  2018   Maruti  [Petrol, +, CNG]  99,081     [Celerio]  Zero Down Payment
#
#        TYPE       PRICE
# ...

# %%
import openpyxl as xls

# %%
delhi.to_excel('CARS_DATA.xlsx')

# %% [markdown]
# ## 818 CARS BANGALORE

# %%
name=[]
f=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in f:
    name.append(i.text)

# %%
year1=[]
ff=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in ff:
    year1.append(i.text.split()[0])

# %%
brand1=[]
fff=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in fff:
    brand1.append(i.text.split()[1])

# %%
model1=[]
ffff=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in ffff:
    model1.append(i.text.split()[2:])

# %%
details=[]
g=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in g:
    details.append(i.text)

# %%
km1=[]
gg=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in gg:
    km1.append(i.text.split()[0])

# %%
own1=[]
ggg=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in ggg:
    own1.append(i.text.split()[2])

# %%
type1=[]
gggg=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in gggg:
    type1.append(i.text.split()[4:7])

# %%
price1=[]
h=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in h:
    price1.append(i.text)

# %%
zdp1=[]
hh=driver.find_elements(By.XPATH,'//span[@class="_3X7mV _2H07I"]')
for i in hh:
    zdp1.append(i.text)

# %%
style=[]
ju=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in ju[0:835]:
    style.append(i.text.split()[-1])

# %%
style
# Out:
# ['Manual',
#  'Manual',
#  'TONE',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'CVT',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  '6STR',
#  'Manual',
#  'TURBO',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'MT',
#  'Automatic',
#  'ZXI',
#  'Manual',
#  'Manual',
#  'Manual',
#  'MT',
#  'Manual',
#  'MT',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'ZXI',
#  'Manual',
#  '1.0',
#  'Manual',
#  'Manual',
#  '1.2',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  '1.0',
#  '1.0',
#  'Manual',
#  'Manual',
# ...

# %%
print(len(price1),len(brand1),len(type1),len(own1),len(km1),len(model1),len(year1),len(style))
# Out:
# 835 835 835 835 835 835 835 835

# %%
bangalore=pd.DataFrame({'YEAR':year1,'BRAND':brand1,'MODEL1':model1,'TYPE':type1,'KM':km1,'OWN':own1,'PRICE':price1,'MAKE':style})

# %%
bangalore
# Out:
#      YEAR    BRAND        MODEL1      TYPE      KM  OWN       PRICE       MAKE
# 0    2013   Maruti   [Alto, 800]  [Petrol]  15,999  1st   ₹2,74,599     Manual
# 1    2011   Maruti        [Ritz]  [Petrol]  28,022  1st   ₹3,77,999     Manual
# 2    2022      KIA       [SONET]  [Diesel]   3,704  1st  ₹16,40,299       TONE
# 3    2010  Hyundai         [i10]  [Petrol]  39,804  1st   ₹2,97,999     Manual
# 4    2014  Hyundai         [i20]  [Petrol]  55,910  1st   ₹4,32,899     Manual
# ..    ...      ...           ...       ...     ...  ...         ...        ...
# 830  2016   Maruti     [Celerio]  [Petrol]  44,978  1st   ₹4,71,199  Automatic
# 831  2016  Hyundai         [i10]  [Petrol]  25,053  1st   ₹4,34,499     Manual
# 832  2020   Maruti   [S, PRESSO]  [Petrol]  26,288  1st   ₹5,22,599  Automatic
# 833  2019  Hyundai  [Grand, i10]  [Petrol]   4,096  1st   ₹6,11,399     Manual
# 834  2017   Maruti   [Alto, K10]  [Petrol]   9,356  1st   ₹4,30,699     Manual
#
# [835 rows x 8 columns]

# %%
bangalore.to_excel('BANG_CARS_DATA.xlsx')

# %% [markdown]
# ## 447 CARS IN MUMBAI

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=2378&pinId=400001')

# %%
year2=[]
qq=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in qq:
    year2.append(i.text.split()[0])

# %%
brand2=[]
ww=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in ww:
    brand2.append(i.text.split()[1])

# %%
model2=[]
www=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in www:
    model2.append(i.text.split()[2:])

# %%
km2=[]
pl=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in pl:
    km2.append(i.text.split()[0])

# %%
own2=[]
ppl=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in ppl:
    own2.append(i.text.split()[2])

# %%
make2=[]
pppl=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in pppl:
    make2.append(i.text.split()[4:])

# %%
type2=[]
op=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in op:
    type2.append(i.text.split()[-1])

# %%
price2=[]
opl=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in opl:
    price2.append(i.text)

# %%
print(len(price2),len(type2),len(make2),len(own2),len(km2),len(brand2),len(year2),len(model2))
# Out:
# 457 457 457 457 457 457 457 457

# %%
mumbai=pd.DataFrame({'YEAR':year2,'BRAND':brand2,'MAKE':make2,'TYPE':type2,'OWNERSHIP':own2,'KM':km2,'PRICE':price2,'MODEL':model2})

# %%
mumbai
# Out:
#      YEAR     BRAND      MAKE       TYPE OWNERSHIP      KM       PRICE  \
# 0    2011   Hyundai  [Petrol]     Manual       2nd  47,979   ₹1,87,599
# 1    2010     Honda  [Petrol]     Manual       2nd  46,821   ₹2,85,099
# 2    2015   Hyundai  [Petrol]     Manual       2nd  42,271   ₹3,01,699
# 3    2013    Maruti  [Petrol]     Manual       1st  37,591   ₹4,14,699
# 4    2013    Maruti  [Petrol]     Manual       1st  46,227   ₹4,25,899
# ..    ...       ...       ...        ...       ...     ...         ...
# 452  2020   Renault  [Petrol]     Manual       1st  27,280   ₹6,99,299
# 453  2015      Ford  [Diesel]     Manual       1st  44,319   ₹6,45,699
# 454  2019  Mahindra  [Diesel]        STR       1st  84,435   ₹8,45,599
# 455  2020     Honda  [Petrol]  Automatic       1st  11,546  ₹13,13,399
# 456  2022    Maruti  [Petrol]     Manual       1st      97  ₹12,51,299
#
#               MODEL
# 0    [Santro, Xing]
# 1            [City]
# 2             [i10]
# 3           [Swift]
# ...

# %%
mumbai.to_excel('MUMBAI_CARS.xlsx')

# %% [markdown]
# ## 259 KOLKATA DATA

# %%
brand3=[]
pi=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in pi:
    brand3.append(i.text.split()[1])

# %%
year3=[]
pii=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in pii:
    year3.append(i.text.split()[0])

# %%
model3=[]
piii=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in piii:
    model3.append(i.text.split()[2:])

# %%
type3=[]
lp=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in lp:
    type3.append(i.text.split()[-1])

# %%
km3=[]
tt=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in tt:
    km3.append(i.text.split()[0])

# %%
own3=[]
ttt=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in ttt:
    own3.append(i.text.split()[2])

# %%
make3=[]
tttt=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in tttt:
    make3.append(i.text.split()[4:])

# %%
price3=[]
gt=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in gt:
    price3.append(i.text)

# %%
print(len(price3),len(make3),len(own3),len(km3),len(type3),len(model3),len(brand3),len(year3))
# Out:
# 259 259 259 259 259 259 259 259

# %%
kolkata=pd.DataFrame({'YEAR':year3,'BRAND':brand3,'MODEL':model3,'TYPE':type3,'OWNERSHIP':own3,'MAKE':make3,'KM':km3,'PRICE':price3})

# %%
kolkata
# Out:
#      YEAR     BRAND           MODEL    TYPE OWNERSHIP      MAKE      KM  \
# 0    2020    Maruti         [Swift]  Manual       1st  [Petrol]   2,944
# 1    2015   Hyundai           [i10]  Manual       2nd  [Petrol]  32,640
# 2    2022  Mahindra   [BOLERO, NEO]      10       1st  [Diesel]   1,271
# 3    2018   Hyundai           [Eon]  Manual       1st  [Petrol]   2,624
# 4    2014    Maruti  [Swift, Dzire]  Manual       2nd  [Petrol]  25,911
# ..    ...       ...             ...     ...       ...       ...     ...
# 254  2017    Maruti        [Ertiga]  Manual       1st  [Petrol]  52,930
# 255  2014      Ford      [Ecosport]  Manual       1st  [Petrol]  38,203
# 256  2011    Toyota         [Etios]  Manual       1st  [Petrol]  50,077
# 257  2012   Hyundai           [i20]  Manual       2nd  [Petrol]  82,883
# 258  2021      Tata         [NEXON]  Manual       1st  [Petrol]   6,468
#
#           PRICE
# 0     ₹6,20,999
# 1     ₹2,71,899
# 2    ₹12,27,549
# 3     ₹3,40,599
# ...

# %%
kolkata.to_excel('Kolkata_cars.xlsx')

# %% [markdown]
# ## 910 CARS IN NOIDA

# %%
year4=[]
kj=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in kj:
    year4.append(i.text.split()[0])

# %%
brand4=[]
kjj=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in kj:
    brand4.append(i.text.split()[1])

# %%
model4=[]
kjjj=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in kjj:
    model4.append(i.text.split()[2:])

# %%
type4=[]
hy=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in hy:
    type4.append(i.text.split()[-1])

# %%
km4=[]
vv=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in vv:
    km4.append(i.text.split()[0])

# %%
own4=[]
vvv=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in vvv:
    own4.append(i.text.split()[2])

# %%
make4=[]
vvvv=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in vvvv:
    make4.append(i.text.split()[4:])

# %%
price4=[]
kk=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in kk:
    price4.append(i.text)

# %%
print(len(price4),len(year4),len(brand4),len(make4),len(type4),len(own4),len(km4),len(model4))
# Out:
# 910 910 910 910 910 910 910 910

# %%
noida=pd.DataFrame({'YEAR':year4,'BRAND':brand4,'MODEL':model4,'TYPE':type4,'OWNERSHIP':own4,'MAKE':make4,'KM':km4,'PRICE':price4})

# %%
noida
# Out:
#      YEAR    BRAND             MODEL    TYPE OWNERSHIP      MAKE        KM  \
# 0    2020  Hyundai      [Grand, i10]  Manual       1st  [Petrol]     6,470
# 1    2011  Hyundai             [i10]  Manual       1st  [Petrol]    45,437
# 2    2017  Hyundai      [Grand, i10]  Manual       1st  [Petrol]     7,189
# 3    2014  Hyundai      [Grand, i10]  Manual       3rd  [Petrol]    11,855
# 4    2011   Maruti   [Wagon, R, 1.0]  Manual       2nd  [Petrol]    47,706
# ..    ...      ...               ...     ...       ...       ...       ...
# 905  2015  Renault          [Duster]  Manual       1st  [Diesel]    55,669
# 906  2014  Renault          [Duster]  Manual       1st  [Diesel]  1,59,926
# 907  2015  Renault          [Duster]  Manual       1st  [Diesel]    65,308
# 908  2016   Maruti  [Vitara, Brezza]  Manual       1st  [Diesel]    57,336
# 909  2013   Maruti    [Swift, Dzire]  Manual       2nd  [Petrol]    60,661
#
#          PRICE
# 0    ₹6,08,399
# 1    ₹2,79,399
# 2    ₹5,33,199
# ...

# %%
noida.to_excel('Noida_cars.xlsx')

# %% [markdown]
# ## CARS 24 GURGAON 918

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=5&pinId=122001')

# %%
year5=[]
yy=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in yy:
    year5.append(i.text.split()[0])

# %%
brand5=[]
yyy=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in yyy:
    brand5.append(i.text.split()[1])

# %%
model5=[]
yyyy=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in yyyy:
    model5.append(i.text.split()[2:])

# %%
km5=[]
kk=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in kk:
    km5.append(i.text.split()[0])

# %%
own5=[]
kkk=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in kkk:
    own5.append(i.text.split()[2])

# %%
make5=[]
kkkk=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in kkkk:
    make5.append(i.text.split()[4:])

# %%
type5=[]
oy=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in oy:
    type5.append(i.text.split()[-1])

# %%
price5=[]
hh=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in hh:
    price5.append(i.text)

# %%
print(len(type5),len(make5),len(own5),len(km5),len(year5),len(brand5),len(model5),len(price5))
# Out:
# 918 918 918 918 918 918 918 918

# %%
gurgaon=pd.DataFrame({'YEAR':year5,'BRAND':brand5,'MODEL':model5,'TYPE':type5,'OWNERSHIP':own5,'MAKE':make5,'KM':km5,'PRICE':price5})

# %%
gurgaon
# Out:
#      YEAR    BRAND       MODEL       TYPE OWNERSHIP              MAKE      KM  \
# 0    2020   Maruti    [Baleno]     Manual       1st          [Petrol]  16,054
# 1    2019     Jeep   [Compass]  Automatic       1st          [Petrol]  23,525
# 2    2018     Jeep   [Compass]     Manual       1st          [Diesel]  79,397
# 3    2021  Hyundai      [AURA]     Manual       1st          [Petrol]  26,389
# 4    2020   Maruti    [Baleno]     Manual       2nd          [Petrol]  10,838
# ..    ...      ...         ...        ...       ...               ...     ...
# 913  2021  Renault     [Kiger]         MT       1st  [Petrol, +, CNG]  24,020
# 914  2018    Honda     [Amaze]  Automatic       1st          [Petrol]  11,825
# 915  2020      KIA    [SELTOS]  Automatic       1st          [Diesel]  41,500
# 916  2021  Hyundai  [NEW, I20]        DCT       1st          [Petrol]  17,609
# 917  2020    Honda      [City]     Manual       1st          [Petrol]  16,253
#
#           PRICE
# ...

# %%
gurgaon.to_excel('GURGAON.xlsx')

# %% [markdown]
# ##  CARS DEKHO -DELHI 600

# %%
driver.get('https://www.cardekho.com/used-cars+in+new-delhi')

# %%
price22=[]
ff=driver.find_elements(By.XPATH,'//span[@class="amnt "]')
for i in ff[0:600]:
        price22.append(i.text)

# %%
km22=[]
cc=driver.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]')
for i in cc[0:600]:
    km22.append(i.text.split()[0])

# %%
make22=[]
ccc=driver.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]')
for i in ccc[0:600]:
    make22.append(i.text.split()[1])

# %%
year22=[]
g=driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]')
for i in g[0:600]:
    year22.append(i.text.split()[0])

# %%
brand22=[]
gg=driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]')
for i in gg[0:600]:
    brand22.append(i.text.split()[1])

# %%
model22=[]
ggg=driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]')
for i in ggg[0:600]:
    model22.append(i.text.split()[2:4])

# %%
links=[]
f=driver.find_elements(By.XPATH,'//a[@title]')
for i in f[91:900]:
    links.append(i.get_attribute('href'))

# %%
links.remove('https://www.cardekho.com/used-petrol+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-diesel+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-cng+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-electric+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-lpg+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-hyundai-creta+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-mahindra-thar+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-suv+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-maruti-alto-800+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-maruti-swift+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-petrol+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-hyundai-i20+cars+in+new-delhi')

# %%
links.remove('https://www.cardekho.com/used-manual+cars+in+new-delhi')

# %%
len(links)
# Out:
# 775

# %%
linkss=links[0:600]

# %%
linkss
# Out:
# ['https://www.cardekho.com/buy-used-car-details/used-Maruti-Baleno-1.2-Delta-cars-Gurgaon_22b35291-04ae-46da-a662-cd17e29fed2a.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Swift-Amt-Zxi-cars-Noida_3699f198-c016-498a-a1e0-9980c07aba04.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Baleno-1.2-Delta-cars-New-Delhi_ea4f46a5-173c-4f6d-abc6-b36cfdbbd14c.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Swift-Dzire-Vxi-cars-Noida_9c9f7f1b-6e11-44f9-a49c-93ac28c33e82.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Toyota-Etios-Liva-1.2-G-cars-Gurgaon_beb609cb-8b04-40c9-bfd1-55a442466006.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Ciaz-Alpha-Bsiv-cars-New-Delhi_aefee77d-00d3-4923-a552-8f3ce67abe81.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Tata-Nexon-Xza-Plus-Amt-cars-Noida_ce63e1b6-b3fc-4117-a70f-30306d899609.htm',
# ...

# %%
own22=[]

for i in linkss:
    driver.get(i)
    time.sleep(2)
    
    try:
        avb=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[1]/div[4]/div/div/div/ul/li[6]/div/div[2]')
        own22.append(avb.text)
    except NoSuchElementException:
        own22.append('-')

# %%
print(len(own22),len(brand22),len(make22),len(model22),len(km22),len(year22),len(price22),len(type22))
# Out:
# 600 600 600 600 600 600 600 600

# %%
cardekhodelhi=pd.DataFrame({'YEAR':year22,'BRAND':brand22,'MODEL':model22,'TYPE':type22,'OWNERSHIP':own22,'MAKE':make22,'KM':km22,'PRICE':price22})

# %%
cardekhodelhi
# Out:
#      YEAR          BRAND             MODEL    TYPE  OWNERSHIP  \
# 0    2017         Maruti     [Baleno, 1.2]  Petrol  1st Owner
# 1    2020         Maruti      [Swift, AMT]  Petrol  1st Owner
# 2    2016         Maruti     [Baleno, 1.2]  Petrol  1st Owner
# 3    2016         Maruti    [Swift, Dzire]  Petrol  1st Owner
# 4    2018         Toyota     [Etios, Liva]  Petrol  2nd Owner
# ..    ...            ...               ...     ...        ...
# 595  2022            Kia  [Carens, Luxury]  Petrol          -
# 596  2020         Maruti        [Wagon, R]  Petrol          -
# 597  2020        Hyundai     [Verna, VTVT]  Petrol          -
# 598  2020  Mercedes-Benz        [GLC, 200]  Diesel          -
# 599  2020         Toyota  [Innova, Crysta]  Petrol          -
#
#                    MAKE      KM       PRICE
# 0       kmsPetrolManual  48,195   5.50 Lakh
# 1    kmsPetrolAutomatic   6,662   7.03 Lakh
# 2       kmsPetrolManual  29,859   5.45 Lakh
# ...

# %%
cardekhodelhi.to_excel('CARSDEKHODELHI.xlsx')

# %% [markdown]
# ## CARS DEKHO KOLKATA

# %%
driver.get('https://www.cardekho.com/used-cars+in+kolkata')

# %%
year33=[]
ii=driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]')
for i in ii:
    year33.append(i.text.split()[0])

# %%
brand33=[]
iii=driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]')
for i in iii:
    brand33.append(i.text.split()[1])

# %%
model33=[]
iiii=driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]')
for i in iiii:
    model33.append(i.text.split()[2:5])

# %%
price33=[]
pp=driver.find_elements(By.XPATH,'//span[@class="amnt "]')
for i in pp:
    price33.append(i.text)

# %%
km33=[]
k=driver.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]')
for i in k:
    km33.append(i.text.split()[0])

# %%
make33=[]
kk=driver.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]')
for i in kk:
    make33.append(i.text.split()[2])

# %%
type33=[]
kkk=driver.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]')
for i in kkk:
    type33.append(i.text.split()[3])

# %%
link33=[]
l=driver.find_elements(By.XPATH,'//a[@title]')
for i in l:
    link33.append(i.get_attribute('href'))

# %%
len(link33)
# Out:
# 1186

# %%
len(type33)
# Out:
# 1055

# %%
link333=link33[91:1186]

# %%
len(link333)
# Out:
# 1095

# %%
link33.remove('https://www.cardekho.com/used-cars+0-lakh-to-2-lakh+in+kolkata')

# %%
link33.remove('https://www.cardekho.com/used-cars+2-lakh-to-3-lakh+in+kolkata')

# %%
link33.remove('https://www.cardekho.com/used-petrol+cars+in+kolkata')

# %%
link33.remove('https://www.cardekho.com/used-electric+cars+in+kolkata')

# %%
link33.remove('https://www.cardekho.com/used-lpg+cars+in+kolkata')

# %%
link33.remove('https://www.cardekho.com/used-petrol+cars+in+kolkata')

# %%
link333.pop(9)
# Out:
# 'https://www.cardekho.com/used-partner+cars+in+kolkata'

# %%
link333.remove('https://www.cardekho.com/used-cars+0-lakh-to-2-lakh+in+kolkata')

# %%
link33.remove('https://www.cardekho.com/used-trustmark+cars+in+kolkata')

# %%
link33.remove('https://www.cardekho.com/used-value-plus+cars+in+kolkata')

# %%
link33.remove('https://www.cardekho.com/used-partner+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-trustmark+cars+in+kolkata')

# %%
link33.remove('https://www.cardekho.com/used-honda-city+cars+in+kolkata')

# %%
link33.remove('https://www.cardekho.com/used-hatchback+cars+in+kolkata')

# %%
len(link333)
# Out:
# 1086

# %%
link333
# Out:
# ['https://www.cardekho.com/used-car-details/used-Renault-Triber-Rxt-cars-New-Town_f02dc28c-04a7-4028-9034-e0a12920d8f4.htm',
#  'https://www.cardekho.com/used-car-details/used-Jeep-Compass-2.0-Limited-Option-cars-Kolkata_decd59bc-da8c-4bfa-8f6e-eae87bbe875b.htm',
#  'https://www.cardekho.com/used-car-details/used-Toyota-Corolla-Altis-G-cars-Kolkata_dc08a23b-4263-4644-865b-07914b13490e.htm',
#  'https://www.cardekho.com/used-car-details/used-Maruti-Alto-800-Lxi-cars-Kolkata_16c8c922-66e6-415b-b565-e70262d73640.htm',
#  'https://www.cardekho.com/used-car-details/used-Hyundai-Grand-I10-Asta-cars-New-Town_4f9ad2fe-27ab-4dc4-870e-557a2a116dc4.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Baleno-Delta-cars-Kolkata_72ce764d-fc6c-49a6-8d58-360e0e92d5f8.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Swift-Vvt-Vxi-cars-Kolkata_925c28a6-5d10-482b-87b8-55e482b19ca6.htm',
# ...

# %%
link333.remove('https://www.cardekho.com/used-hatchback+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-cars+in+new-town')

# %%
link333.remove('https://www.cardekho.com/used-cars+in+bhopal')

# %%
link333.remove('https://www.cardekho.com/used-cars+in+purnia')

# %%
link333.remove('https://www.cardekho.com/used-convertible+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-sedan+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-suv+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-muv+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-petrol+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-honda-city+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-petrol+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-manual+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-maruti-swift+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-diesel+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-electric+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-lpg+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-cng+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-hyundai-verna+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-maruti-wagon-r+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-maruti-alto-800+cars+in+kolkata')

# %%
link333.remove('https://www.cardekho.com/used-hatchback+cars+in+kolkata')

# %%
len(link333)
# Out:
# 1065

# %%
len(year33)
# Out:
# 1055

# %%
linknew=link333[:1055]

# %%
own33=[]

for i in linknew:
    driver.get(i)
    time.sleep(2)
    
    try:
        avbb=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[3]/div/div/div/div[1]/ul/li[4]/div/div')
        own33.append(avbb.text)
    except NoSuchElementException:
        own33.append('-')

# %%
print(len(own33),len(model33),len(price33),len(brand33),len(year33),len(make33),len(km33),len(type33))
# Out:
# 1055 1055 1055 1055 1055 1055 1055 1055

# %%
carsdekhokol=pd.DataFrame({'YEAR':year33,'BRAND':brand33,'MODEL':model33,'TYPE':type33,'OWNERSHIP':own33,'MAKE':make33,'KM':km33,'PRICE':price33})

# %%
carsdekhokol
# Out:
#       YEAR          BRAND                    MODEL       TYPE    OWNERSHIP  \
# 0     2020        Renault     [Triber, RXT, ₹5.86]     Manual  First Owner
# 1     2017           Jeep  [Compass, 2.0, Limited]     Manual  First Owner
# 2     2013         Toyota      [Corolla, Altis, G]     Manual  First Owner
# 3     2017         Maruti         [Alto, 800, LXI]     Manual  First Owner
# 4     2013        Hyundai       [Grand, i10, Asta]     Manual  First Owner
# ...    ...            ...                      ...        ...          ...
# 1050  2020           Tata    [Yodha, Pickup, Crew]     Manual  First Owner
# 1051  2015        Hyundai       [i20, Sportz, 1.4]     Manual  First Owner
# 1052  2017  Mercedes-Benz           [GLC, 43, AMG]  Automatic  First Owner
# 1053  2012        Hyundai         [EON, Era, Plus]     Manual  First Owner
# 1054  2007         Toyota     [Corolla, AE, ₹1.10]     Manual  First Owner
#
#         MAKE        KM       PRICE
# ...

# %%
carsdekhokol.to_excel('KOLCARSDEKHO.xlsx')

# %% [markdown]
# ## CARS DEKHO MUMBAI

# %%
driver.get('https://www.cardekho.com/used-cars+in+mumbai')

# %%
price66=[]
pt=driver.find_elements(By.XPATH,'//span[@class="amnt "]')
for i in pt[:500]:
    price66.append(i.text)

# %%
km66=[]
tt=driver.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]')
for i in tt[:500]:
    km66.append(i.text.split()[0])

# %%
make66=[]
ttt=driver.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]')
for i in ttt[:500]:
    make66.append(i.text.split()[2])

# %%
type66=[]
tttt=driver.find_elements(By.XPATH,'//div[@class="truncate dotlist-2"]')
for i in tttt[:500]:
    type66.append(i.text.split()[3])

# %%
year66=[]
y=driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]')
for i in y[:500]:
    year66.append(i.text.split()[0])

# %%
brand66=[]
yy=driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]')
for i in yy[:500]:
    brand66.append(i.text.split()[1])

# %%
model66=[]
yyy=driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-7  carsName"]')
for i in yyy[:500]:
    model66.append(i.text.split()[2:4])

# %%
link66=[]
lp=driver.find_elements(By.XPATH,'//a[@title]')
for i in lp[91:625]:
    link66.append(i.get_attribute('href'))

# %%
model66[490:500]
# Out:
# [['Swift', 'Dzire'],
#  ['XUV300', 'W8'],
#  ['Wagon', 'R'],
#  ['Swift', 'Dzire'],
#  ['Swift', 'VXI'],
#  ['Wagon', 'R'],
#  ['Wagon', 'R'],
#  ['Glanza', 'G'],
#  ['Indica', 'Aura'],
#  ['Duster', 'RXZ']]

# %%
len(link66)
# Out:
# 534

# %%
link66.pop(16)
# Out:
# 'https://www.cardekho.com/used-suv+cars+in+mumbai'

# %%
link66.remove('https://www.cardekho.com/used-cars+in+pune')

# %%
link66.remove('https://www.cardekho.com/used-cars+in+ahmedabad')

# %%
link66.remove('https://www.cardekho.com/used-cars+in+thane')

# %%
link66.remove('https://www.cardekho.com/used-cars+in+surat')

# %%
link66.remove('https://www.cardekho.com/used-cars+in+vadodara')

# %%
link66.remove('https://www.cardekho.com/used-cars+in+nashik')

# %%
link66.remove('https://www.cardekho.com/used-cars+in+pimpri-chinchwad')

# %%
link66.remove('https://www.cardekho.com/used-petrol+cars+in+mumbai')

# %%
link66
# Out:
# ['https://www.cardekho.com/buy-used-car-details/used-Hyundai-Santro-Magna-Cng-Bsiv-cars-Mumbai_f3c9dbc4-ff4a-44f4-82b4-41d8301aa6d5.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Baleno-1.2-Delta-cars-Mumbai_80a2adda-1183-4977-8cc1-e5888f94fb32.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Verna-Vtvt-1.6-Sx-Option-cars-Mumbai_c6d6839a-abd0-474d-9d03-5fd27c52db12.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Grand-I10-1.2-Kappa-Sportz-Dual-Tone-cars-Mumbai_8b8cabd2-f858-4239-b700-72c300510efb.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Maruti-Baleno-1.2-Cvt-Alpha-cars-Mumbai_cfd3991c-59ae-4e20-974a-6b446c17598c.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Grand-I10-Asta-cars-Mumbai_39b70439-fdad-4260-a006-1f8e2f950b4a.htm',
#  'https://www.cardekho.com/buy-used-car-details/used-Hyundai-Grand-I10-1.2-Kappa-Asta-cars-Mumbai_718fa438-3a50-4fe9-8c4b-7a179aa1b8a4.htm',
# ...

# %%
link66.pop(21)
# Out:
# 'https://www.cardekho.com/used-electric+cars+in+mumbai'

# %%
link66.remove('https://www.cardekho.com/used-petrol+cars+in+mumbai')

# %%
link66.remove('https://www.cardekho.com/used-lpg+cars+in+mumbai')

# %%
link66.pop(22)
# Out:
# 'https://www.cardekho.com/buy-used-car-details/used-Hyundai-I20-Sportz-1.2-cars-Mumbai_85515531-b7d0-4d9c-8fdf-5ff0e2718804.htm'

# %%
link66.insert(22,'https://www.cardekho.com/buy-used-car-details/used-Hyundai-I20-Sportz-1.2-cars-Mumbai_85515531-b7d0-4d9c-8fdf-5ff0e2718804.htm')

# %%
len(link66)
# Out:
# 507

# %%
link66.remove('https://www.cardekho.com/used-sedan+cars+in+mumbai')

# %%
link66.remove('https://www.cardekho.com/used-manual+cars+in+mumbai')

# %%
link66.remove('https://www.cardekho.com/used-maruti-baleno+cars+in+mumbai')

# %%
link66.remove('https://www.cardekho.com/used-hyundai-i20+cars+in+mumbai')

# %%
link66.remove('https://www.cardekho.com/used-honda-city+cars+in+mumbai')

# %%
link66.remove('https://www.cardekho.com/used-hyundai-creta+cars+in+mumbai')

# %%
link66.remove('https://www.cardekho.com/used-maruti-wagon-r+cars+in+mumbai')

# %%
own66=[]

for i in link66:
    driver.get(i)
    time.sleep(2)
    
    try:
        avbb=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/div/div/main/div/div[1]/div[1]/div[4]/div/div/div/ul/li[6]/div/div[2]')
        own66.append(avbb.text)
    except NoSuchElementException:
        own66.append('-')

# %%
mumbai_carsdekho=pd.DataFrame({'YEAR':year66,'BRAND':brand66,'MODEL':model66,'TYPE':type66,'OWNERSHIP':own66,'MAKE':make66,'KM':km66,'PRICE':price66})

# %%
mumbai_carsdekho
# Out:
#      YEAR    BRAND            MODEL       TYPE  OWNERSHIP    MAKE      KM  \
# 0    2019  Hyundai  [Santro, Magna]     Manual  1st Owner     CNG  61,456
# 1    2017   Maruti    [Baleno, 1.2]     Manual  1st Owner  Petrol  44,295
# 2    2018  Hyundai    [Verna, VTVT]     Manual  1st Owner  Petrol  51,956
# 3    2018  Hyundai     [Grand, i10]     Manual  1st Owner  Petrol  23,900
# 4    2018   Maruti    [Baleno, 1.2]  Automatic  2nd Owner  Petrol  19,647
# ..    ...      ...              ...        ...        ...     ...     ...
# 495  2009   Maruti       [Wagon, R]     Manual          -     LPG  54,542
# 496  2016   Maruti       [Wagon, R]     Manual          -     CNG  74,050
# 497  2021   Toyota      [Glanza, G]  Automatic          -  Petrol   7,965
# 498  2010     Tata   [Indica, Aura]     Manual          -  Petrol  45,894
# 499  2020  Renault    [Duster, RXZ]     Manual          -  Petrol  54,142
#
#           PRICE
# 0     5.30 Lakh
# 1     5.56 Lakh
# 2    10.11 Lakh
# ...

# %%
mumbai_carsdekho.to_excel('MUMBAI_CARDEKHO.xlsx')

# %% [markdown]
# ## CARS 24 PUNE

# %%
driver.get('https://www.cars24.com/buy-used-car?sort=P&storeCityId=2423&pinId=411001')

# %%
year77=[]
y=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in y:
    year77.append(i.text.split()[0])

# %%
brand77=[]
ye=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in ye:
    brand77.append(i.text.split()[1])

# %%
model77=[]
yt=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in yt:
    model77.append(i.text.split()[2:4])

# %%
km77=[]
o=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in o:
    km77.append(i.text.split()[0])

# %%
own77=[]
orr=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in orr:
    own77.append(i.text.split()[2])

# %%
make77=[]
orp=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in orp:
    make77.append(i.text.split()[4:])

# %%
type77=[]
j=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in j:
    type77.append(i.text.split()[-1])

# %%
price77=[]
k=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in k:
    price77.append(i.text)

# %%
price77
# Out:
# ['₹3,43,999',
#  '₹4,69,999',
#  '₹2,20,799',
#  '₹8,65,499',
#  '₹14,38,899',
#  '₹6,84,499',
#  '₹4,52,999',
#  '₹4,72,699',
#  '₹7,01,099',
#  '₹3,12,199',
#  '₹8,44,299',
#  '₹7,34,599',
#  '₹5,02,699',
#  '₹15,18,299',
#  '₹5,46,599',
#  '₹4,15,549',
#  '₹6,68,299',
#  '₹4,02,599',
#  '₹4,65,699',
#  '₹8,33,699',
#  '₹2,62,999',
#  '₹7,84,519',
#  '₹5,13,999',
#  '₹3,10,599',
#  '₹3,41,799',
#  '₹2,33,999',
#  '₹4,47,699',
#  '₹2,25,599',
#  '₹14,02,549',
#  '₹3,83,799',
#  '₹5,82,999',
#  '₹4,22,599',
#  '₹6,87,199',
#  '₹4,82,099',
#  '₹9,21,399',
#  '₹1,96,199',
#  '₹17,94,999',
#  '₹2,86,999',
#  '₹4,84,799',
#  '₹4,57,599',
#  '₹3,20,799',
#  '₹12,50,699',
#  '₹3,13,299',
#  '₹14,40,099',
#  '₹4,82,299',
#  '₹3,20,199',
#  '₹18,62,799',
#  '₹5,33,799',
#  '₹2,95,499',
#  '₹5,20,899',
#  '₹5,53,499',
#  '₹24,38,199',
#  '₹2,99,899',
#  '₹6,13,099',
#  '₹3,39,199',
#  '₹5,01,799',
#  '₹8,36,199',
#  '₹7,29,699',
#  '₹3,00,599',
#  '₹6,30,879',
#  '₹5,09,299',
#  '₹7,32,899',
# ...

# %%
print(len(brand77),len(year77),len(model77),len(km77),len(make77),len(type77),len(own77),len(price77))
# Out:
# 413 413 413 413 413 413 413 413

# %%
pune=pd.DataFrame({'YEAR':year77,'BRAND':brand77,'MODEL':model77,'TYPE':type77,'OWNERSHIP':own77,'MAKE':make77,'KM':km77,'PRICE':price77})

# %%
pune
# Out:
#      YEAR       BRAND             MODEL       TYPE OWNERSHIP      MAKE  \
# 0    2015      Maruti        [Wagon, R]     Manual       1st  [Petrol]
# 1    2016      Maruti    [Swift, Dzire]     Manual       1st  [Petrol]
# 2    2012      Maruti       [Alto, K10]     Manual       3rd  [Petrol]
# 3    2021      Nissan         [MAGNITE]        CVT       1st  [Petrol]
# 4    2022         KIA           [SONET]         AE       1st  [Diesel]
# ..    ...         ...               ...        ...       ...       ...
# 408  2017       Honda            [BR-V]  Automatic       1st  [Petrol]
# 409  2016      Maruti  [Vitara, Brezza]     Manual       1st  [Diesel]
# 410  2016    Mahindra          [XUV500]  Automatic       2nd  [Diesel]
# 411  2014  Volkswagen            [Polo]     Manual       2nd  [Petrol]
# 412  2018       Honda           [Amaze]  Automatic       1st  [Petrol]
#
#            KM       PRICE
# 0      32,489   ₹3,43,999
# 1    1,85,652   ₹4,69,999
# 2      34,402   ₹2,20,799
# ...

# %%
pune.to_excel('PUNE_CARS24.xlsx')

# %% [markdown]
# ## CARS 24 HYDERABAD

# %%
year88=[]
b=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in b:
    year88.append(i.text.split()[0])

# %%
brand88=[]
cb=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in cb:
    brand88.append(i.text.split()[1])

# %%
model88=[]
cbg=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in cbg:
    model88.append(i.text.split()[2:4])

# %%
km88=[]
ft=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in ft:
    km88.append(i.text.split()[0])

# %%
own88=[]
fft=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in fft:
    own88.append(i.text.split()[2])

# %%
make88=[]
fftt=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in fftt:
    make88.append(i.text.split()[4:])

# %%
type88=[]
lp=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in lp:
    type88.append(i.text.split()[-1])

# %%
price88=[]
pb=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in pb:
    price88.append(i.text)

# %%
type88=[]
opp=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in opp:
    type88.append(i.text.split()[-1])

# %%
print(len(brand88),len(year88),len(model88),len(km88),len(make88),len(type88),len(own88),len(price88))
# Out:
# 464 464 464 464 464 464 464 464

# %%
hyderabad=pd.DataFrame({'YEAR':year88,'BRAND':brand88,'MODEL':model88,'TYPE':type88,'OWNERSHIP':own88,'MAKE':make88,'KM':km88,'PRICE':price88})

# %%
hyderabad
# Out:
#      YEAR       BRAND        MODEL       TYPE OWNERSHIP      MAKE      KM  \
# 0    2020      Maruti      [Swift]     Manual       2nd  [Petrol]  10,056
# 1    2017      Datsun   [Go, Plus]     Manual       1st  [Petrol]  22,645
# 2    2020      Maruti      [Swift]     Manual       2nd  [Petrol]  56,084
# 3    2022      Maruti      [Swift]       TONE       1st  [Petrol]     1st
# 4    2019     Renault       [Kwid]     Manual       1st  [Petrol]  39,109
# ..    ...         ...          ...        ...       ...       ...     ...
# 459  2019        Tata      [NEXON]       Tone       1st  [Diesel]     1st
# 460  2019      Maruti     [Baleno]     Manual       1st  [Petrol]  34,626
# 461  2017  Volkswagen       [Ameo]  Automatic       1st  [Diesel]  89,638
# 462  2021    Mahindra    [MARAZZO]        STR       1st  [Diesel]     1st
# 463  2019        Ford  [FREESTYLE]     Manual       2nd  [Diesel]  74,952
#
#           PRICE
# 0     ₹6,41,799
# 1     ₹3,11,899
# 2     ₹6,34,119
# ...

# %%
hyderabad.to_csv('HYDBCARS24.xlsx')

# %%
hyderabad.to_excel('HYDBCARS24.xlsx')

# %% [markdown]
# ## CHENNAI

# %%
year99=[]
z=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in z:
    year99.append(i.text.split()[0])

# %%
brand99=[]
tz=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in tz:
    brand99.append(i.text.split()[1])

# %%
model99=[]
tzz=driver.find_elements(By.XPATH,'//h2[@class="_3FpCg"]')
for i in tzz:
    model99.append(i.text.split()[2:4])

# %%
type99=[]
iy=driver.find_elements(By.XPATH,'//p[@class="cvakB"]')
for i in iy:
    type99.append(i.text.split()[-1])

# %%
km99=[]
pp=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in pp:
    km99.append(i.text.split()[0])

# %%
own99=[]
pptt=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in pptt:
    own99.append(i.text.split()[2])

# %%
make99=[]
ppttt=driver.find_elements(By.XPATH,'//ul[@class="bVR0c"]')
for i in ppttt:
    make99.append(i.text.split()[4:])

# %%
price99=[]
jj=driver.find_elements(By.XPATH,'//div[@class="_7udZZ"]')
for i in jj:
    price99.append(i.text)

# %%
print(len(brand99),len(year88),len(model99),len(km99),len(make99),len(type99),len(own99),len(price99))
# Out:
# 419 464 419 419 419 419 419 419

# %%
chennai=pd.DataFrame({'YEAR':year99,'BRAND':brand99,'MODEL':model99,'TYPE':type99,'OWNERSHIP':own99,'MAKE':make99,'KM':km99,'PRICE':price99})

# %%
chennai
# Out:
#      YEAR   BRAND          MODEL    TYPE OWNERSHIP      MAKE        KM  \
# 0    2012   Honda         [City]  Manual       1st  [Petrol]    36,212
# 1    2022    Tata       [ALTROZ]  Manual       1st  [Petrol]       269
# 2    2011  Maruti  [Zen, Estilo]  Manual       2nd  [Petrol]    32,745
# 3    2020  Maruti        [Swift]  Manual       1st  [Petrol]    15,750
# 4    2021  Nissan      [MAGNITE]     CVT       2nd  [Petrol]     6,808
# ..    ...     ...            ...     ...       ...       ...       ...
# 414  2014  Nissan      [Terrano]  Manual       1st  [Diesel]  1,96,317
# 415  2018  Maruti     [Wagon, R]  Manual       1st  [Petrol]    22,253
# 416  2017   Honda         [Jazz]  Manual       1st  [Petrol]    54,288
# 417  2019  Maruti         [Alto]  Manual       1st  [Petrol]    44,146
# 418  2017  Datsun     [Go, Plus]  Manual       1st  [Petrol]    36,579
#
#          PRICE
# 0    ₹4,79,799
# 1    ₹6,74,899
# 2    ₹2,41,599
# 3    ₹6,71,999
# 4    ₹8,79,199
# ..         ...
# ...

# %%
chennai.to_excel('CHENNAI_CARS24.xlsx')
